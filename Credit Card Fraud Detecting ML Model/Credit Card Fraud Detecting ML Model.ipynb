# %%
# IMPORTING NECESSARY LIBRARIES
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
# IMPORTING DATASET
data = pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# CHECKING NULL VALUES
data.isnull().sum().sum()
# Out:
# 0

# %%
# SHAPE OF DATA
data.shape
# Out:
# (284807, 31)

# %%
# CHECKING DUPLICATE DATA
data[data.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
# DROPING DUPLICATE DATA
data.drop_duplicates(inplace=True)

# %%
# SHAPE OF DATA AFTER DROPING DUPLICATE VALUES
data.shape
# Out:
# (283726, 31)

# %%
# STATISTICAL ANALYSIS
data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
# NUMBER OF FRAUD AND LEGIT TRANSACTIONS
data.Class.value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
# DATA PREPROCESSING
data['Class'] = data['Class'].replace(to_replace=[0,1],value=['Legit','Fraud'])

# %%
data.Class.value_counts()
# Out:
# Legit    283253
# Fraud       473
# Name: Class, dtype: int64

# %%
Legit = data[data['Class']=='Legit']
Fraud = data[data['Class']=='Fraud']

# %%
print(Legit.shape)
print(Fraud.shape)
# Out:
# (283253, 31)
# (473, 31)

# %%
# REDUCING UNBALANCED DATA TO EQUAL 
Legit_1 = Legit.sample(473,random_state=4)

# %%
new_data = pd.concat([Legit_1,Fraud],axis=0,ignore_index=True)

# %%
new_data.Class.value_counts()
# Out:
# Legit    473
# Fraud    473
# Name: Class, dtype: int64

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# Fraud  80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
# Legit  94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# Fraud -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
# Legit  0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# Fraud  0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
# Legit -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
#
#            Amount
# Class
# Fraud  123.871860
# Legit   88.413575
#
# [2 rows x 30 columns]

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# Fraud  80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
# Legit  92375.864693  0.115377  0.028837 -0.075327  0.032068  0.030810
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# Fraud -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.466550
# Legit  0.148639 -0.015255  0.058254 -0.053537  ...  0.001811 -0.022211
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# Fraud  0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
# Legit -0.022835  0.000577  0.034494 -0.015552  0.002787  0.021373  0.003568
#
#            Amount
# Class
# Fraud  123.871860
# Legit   81.309218
#
# [2 rows x 30 columns]

# %%
# SEPARATING FEATURES AND TARGET VARIABLES
X = new_data.drop(columns='Class')
Y = new_data['Class']

# %%
# SPLITTING DATA TO TRAIN AND TEST
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=.25,random_state=1)

# %%
# ML MODEL FITTING MODEL WITH TRAIN DATA
LR = LogisticRegression()
LR_model = LR.fit(x_train,y_train)

# %%
# MODEL PREDICTION
y_train_pred = LR_model.predict(x_train)
y_test_pred = LR_model.predict(x_test)

# %%
# MODEL ACCURACY
print(f'Model accuracy on Training data: {round(accuracy_score(y_train,y_train_pred)*100,2)}%')
print(f'Model accuracy on Test data: {round(accuracy_score(y_test,y_test_pred)*100,2)}%')
# Out:
# Model accuracy on Training data: 93.37%
# Model accuracy on Test data: 92.41%

# %%
# MODEL EVALUATION
Fraud_list = list(Y[Y=='Fraud'].index)
Legit_list = list(Y[Y=='Legit'].index)
Predicted_Fraud = []
Predicted_Legit = []

# %%
for i in Fraud_list:
    Fr = X.iloc[i].values.reshape(1,-1)
    Fr_ = LR_model.predict(Fr)
    Predicted_Fraud.append(Fr_)
for j in Legit_list:
    Le = X.iloc[j].values.reshape(1,-1)
    Le_ = LR_model.predict(Le)
    Predicted_Legit.append(Le_)

# %%
Fraud = pd.Series(Predicted_Fraud)
Legit = pd.Series(Predicted_Legit)

# %%
print(f'Out of {len(Fraud_list)} FRAUD TRANSACTION DATA Logistic Regression Model Predicted')
print(Fraud.value_counts().to_string())
# Out:
# Out of 473 FRAUD TRANSACTION DATA Logistic Regression Model Predicted
# [Fraud]    433
# [Legit]     40

# %%
print(f'Out of {len(Legit_list)} LEGIT TRANSACTION DATA Logistic Regression Model Predicted')
print(Legit.value_counts().to_string())
# Out:
# Out of 473 LEGIT TRANSACTION DATA Logistic Regression Model Predicted
# [Legit]    448
# [Fraud]     25
